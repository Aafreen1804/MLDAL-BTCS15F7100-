# %% [markdown]
# <a href="https://colab.research.google.com/github/Aafreen1804/MLDAL-BTCS15F7100-/blob/master/program_10_MLDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.io import push_notebook


def local_regression(x0, X, Y, tau):
    # add bias term
    x0 = np.r_[1, x0]  # Add one to avoid the loss in information
    X = np.c_[np.ones(len(X)), X]
    # fit model: normal equations with kernel
    xw = X.T * radial_kernel(x0, X, tau)  # XTranspose * W
    beta = np.linalg.pinv(xw @ X) @ xw @ Y  # @ Matrix Multiplication or Dot Product
    # predict value
    return x0 @ beta  # @ Matrix Multiplication or Dot Product for prediction


def radial_kernel(x0, X, tau):
    return np.exp(np.sum((X - x0) ** 2, axis=1) / (-2 * tau * tau))


# Weight or Radial Kernel Bias Function

n = 1000
# generate dataset
X = np.linspace(-3, 3, num=n)
print("The Data Set ( 10 Samples) X :\n", X[1:10])
Y = np.log(np.abs(X ** 2 - 1) + .5)
print("The Fitting Curve Data Set (10 Samples) Y :\n", Y[1:10])
# jitter X
X += np.random.normal(scale=.1, size=n)
print("Normalised (10 Samples) X :\n",X[1:10])

domain = np.linspace(-3, 3, num=300)
print(" Xo Domain Space(10 Samples) :\n",domain[1:10])

def plot_lwr(tau):
    # prediction through regression
    prediction = [local_regression(x0, X, Y, tau) for x0 in domain]
    plot = figure(plot_width=400, plot_height=400)
    plot.title.text='tau=%g' % tau
    plot.scatter(X, Y, alpha=.3)
    plot.line(domain, prediction, line_width=2, color='red')
    return plot
# Plotting the curves with different tau
show(gridplot([
[plot_lwr(10.), plot_lwr(1.)],
[plot_lwr(0.1), plot_lwr(0.01)]
]))
# Out:
# The Data Set ( 10 Samples) X :
#  [-2.99399399 -2.98798799 -2.98198198 -2.97597598 -2.96996997 -2.96396396
#  -2.95795796 -2.95195195 -2.94594595]
# The Fitting Curve Data Set (10 Samples) Y :
#  [2.13582188 2.13156806 2.12730467 2.12303166 2.11874898 2.11445659
#  2.11015444 2.10584249 2.10152068]
# Normalised (10 Samples) X :
#  [-2.83273804 -2.81020132 -3.0496668  -3.21418736 -3.11003377 -3.1233863
#  -2.8734733  -2.78953111 -3.08111988]
#  Xo Domain Space(10 Samples) :
#  [-2.97993311 -2.95986622 -2.93979933 -2.91973244 -2.89966555 -2.87959866
#  -2.85953177 -2.83946488 -2.81939799]

# %%
from numpy import *
import operator
from os import listdir
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy.linalg
from scipy.stats.stats import pearsonr
# load data points
data = pd.read_csv('/content/data10_tips.csv')
data.fillna(method='ffill') ##tried filling the nan values using fillna
bill = array(data.total_bill)
tip = array(data.tip)
#preparing and add 1 in bill
mbill = mat(bill)
mtip = mat(tip)
m= shape(mbill)[1]
one = mat(ones(m))
X= hstack((one.T,mbill.T))
#set k here
ypred = localWeightRegression(X,mtip,0.2)
SortIndex = X[:,1].argsort(0)
xsort = X[SortIndex][:,0]

def kernel(point,xmat, k):
 m,n = shape(xmat)
 weights = mat(eye((m)))
 for j in range(m):
   diff = point - X[j]
   weights[j,j] = exp(diff*diff.T/(-2.0*k**2))
 return weights
def localWeight(point,xmat,ymat,k):
 wei = kernel(point,xmat,k)
 W = (X.T*(wei*X)).I*(X.T*(wei*ymat.T))
 return W

def localWeightRegression(xmat,ymat,k):
 m,n = shape(xmat)
 ypred = zeros(m)
 for i in range(m):
   ypred[i] = xmat[i]*localWeight(xmat[i],xmat,ymat,k)
 return ypred


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(bill,tip, color='green')
ax.plot(xsort[:,1],ypred[SortIndex], color = 'red', linewidth=5)
plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c991f9407885> in <module>()
#      19 X= hstack((one.T,mbill.T))
#      20 #set k here
# ---> 21 ypred = localWeightRegression(X,mtip,0.2)
#      22 SortIndex = X[:,1].argsort(0)
#      23 xsort = X[SortIndex][:,0]
#
# <ipython-input-20-8a526d3533ab> in localWeightRegression(xmat, ymat, k)
#      23  ypred = zeros(m)
#      24  for i in range(m):
# ---> 25    ypred[i] = xmat[i]*localWeight(xmat[i],xmat,ymat,k)
#      26  return ypred
#      27 # load data points
#
# <ipython-input-20-8a526d3533ab> in localWeight(point, xmat, ymat, k)
#      16 def localWeight(point,xmat,ymat,k):
#      17  wei = kernel(point,xmat,k)
# ---> 18  W = (X.T*(wei*X)).I*(X.T*(wei*ymat.T))
#      19  return W
#      20
#
# /usr/local/lib/python3.6/dist-packages/numpy/matrixlib/defmatrix.py in I(self)
#     835         else:
# ...

# %%
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0           NaN   NaN     NaN    NaN   NaN     NaN   NaN
# 1         16.99  1.01  Female     No   Sun  Dinner   2.0
# 2         16.99  1.01  Female     No   Sun  Dinner   2.0
# 3         10.34  1.66    Male     No   Sun  Dinner   3.0
# 4         10.34  1.66    Male     No   Sun  Dinner   3.0
# ..          ...   ...     ...    ...   ...     ...   ...
# 483       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 484       22.67  2.00    Male    Yes   Sat  Dinner   2.0
# 485       17.82  1.75    Male     No   Sat  Dinner   2.0
# 486       17.82  1.75    Male     No   Sat  Dinner   2.0
# 487       18.78  3.00  Female     No  Thur  Dinner   2.0
#
# [488 rows x 7 columns]
